# %% [markdown]
# # HW2 - Plotting with `matplotlib`

# %% [markdown]
# **Spring 2020 | Python for Neuroscientists**
#
#
# This HW will focus on plotting with the `matplotlib` library. We will use the coronavirus data, which can be downloaded as a csv file from the following Johns Hopkins University website. The data is updated daily here:
#
# https://data.humdata.org/dataset/novel-coronavirus-2019-ncov-cases
#
# This data is simply cumulative confirmed cases for each country.

# %%
# pandas 
import pandas as pd

# matplotlib
import matplotlib.pyplot as plt

# seaborn
import seaborn as sns

# %% [markdown]
# ## Load the csv file
#
# Make sure that the csv file and the .ipynb are in the same directory

# %%
df = pd.read_csv('time_series_covid19_confirmed_global.csv') # this is pandas function

# %% [markdown]
# This loads a table, or pandas "dataframe." We will use pandas to extract data from the table. We can look at the contents of the table:

# %%
df
# Out:
#                        Province/State          Country/Region        Lat  \
# 0                                 NaN             Afghanistan  33.000000
# 1                                 NaN                 Albania  41.153300
# 2                                 NaN                 Algeria  28.033900
# 3                                 NaN                 Andorra  42.506300
# 4                                 NaN                  Angola -11.202700
# 5                                 NaN     Antigua and Barbuda  17.060800
# 6                                 NaN               Argentina -38.416100
# 7                                 NaN                 Armenia  40.069100
# 8        Australian Capital Territory               Australia -35.473500
# 9                     New South Wales               Australia -33.868800
# 10                 Northern Territory               Australia -12.463400
# 11                         Queensland               Australia -28.016700
# ...

# %% [markdown]
# Let's look at the stats for Italy

# %%
df_italy = df[df['Country/Region'] == 'Italy'] # this is one way to select Italy from the dataframe
df_italy.head() # this displays the
# Out:
#     Province/State Country/Region   Lat  Long  1/22/20  1/23/20  1/24/20  \
# 137            NaN          Italy  43.0  12.0        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  4/8/20  4/9/20  4/10/20  4/11/20  \
# 137        0        0        0  ...  139422  143626   147577   152271
#
#      4/12/20  4/13/20  4/14/20  4/15/20  4/16/20  4/17/20
# 137   156363   159516   162488   165155   168941   172434
#
# [1 rows x 91 columns]

# %%
df_italy1 = df_italy.set_index('Country/Region', drop = True) # set pandas dataframe index to country
df_italy2 = df_italy1.drop(columns=['Lat','Long','Province/State'])

data_italy = df_italy2.loc['Italy','2/20/20':'4/17/20'] # select dates through April 17, 2020

# %% [markdown]
# Note that it would be cleaner to write the following:
# > `df_italy = df_italy.set_index('Country/Region', drop = True)`
#
# > `df_italy = df_italy.drop(columns=['Lat','Long','Province/State'])`
#
# > `data_italy = df_italy.loc['Italy','2/20/20':'4/17/20']`

# %% [markdown]
# # Part 1: Plot the Data from Italy

# %%
plt.plot(data_italy.values,'.-')
plt.xlabel('days')
plt.show()

# %% [markdown]
# ## 1a Change the color of the line

# %%
# your code here
plt.plot(data_italy.values,'.-',c='r')
plt.xlabel('days')
plt.show()

# %% [markdown]
# ## 1b Change the thickness of the line

# %%
# your code here
plt.plot(data_italy.values,'.-',c='r',linewidth=1)
plt.xlabel('days')
plt.show()

# %% [markdown]
# ## 1c Add a label the y-axis

# %%
# your code here
plt.plot(data_italy.values,'.-',c='r',linewidth=1)
plt.xlabel('days')
plt.ylabel('cumulative confirmed cases')
plt.show()

# %% [markdown]
# ## 1d Add a title

# %%
# your code here
plt.plot(data_italy.values,'.-',c='r',linewidth=1)
plt.xlabel('days')
plt.ylabel('cumulative confirmed cases')
plt.title('Covid-19 Cases in Italy')
plt.show()

# %% [markdown]
# ## 1e Resize the figure
# Note that we can plot with the calendar date using `data_italy.index`

# %%
# resize this figure here
fig = plt.figure(figsize=(10,5))

plt.plot(data_italy.index,data_italy.values,'.-')
plt.xticks(rotation=90) # rotate the xticks so text is not so tight
plt.xlabel('calendar date')
plt.show()

# %% [markdown]
# ## Part 2: Plotting US and Italy Data
#
# We can extract the data for the US from the dataframe

# %%
df_us = df[df['Country/Region'] == 'US']
df_us = df_us.set_index('Country/Region', drop = True) # set pandas dataframe index to country
df_us = df_us.drop(columns=['Lat','Long','Province/State'])

data_us = df_us.loc['US','2/28/20':'4/17/20']

# %% [markdown]
# ## 2a: Plot Italy and US data in two axes
#
# Use subplots and assign separate colors to each country. Set the same limits on the y-axis for both subplots

# %%
# use 
fig,ax = plt.subplots(1,2,figsize=(15,5)) # or whatever dimensions you like

ax[0].plot(data_italy.values,'o-',c='b',linewidth=3,label='Italy')
ax[1].plot(data_us.values,'o-',c='r',linewidth=3,label='USA')

ax[0].set_title('Covid-19 in Italy',c='b')
ax[1].set_title('Covid-19 in USA',c='r')

for a in ax:
    a.set_ylim(0,700000)
    a.set_xlabel('days from tracking',fontsize=14)
    a.set_ylabel('cumulative confirmed cases',fontsize=14)
    #a.legend(fontsize=10)

plt.show()

# %% [markdown]
# ## 2b: Plot Italy and US data in the same plot
#
# Use the same colors as above, and include a legend

# %%
# your code here

fig,ax = plt.subplots(1,1,figsize=(15,5)) # or whatever dimensions you like

ax.plot(data_italy.values,'-',c='b',linewidth=3,label='Italy')
ax.plot(data_us.values,'-',c='r',linewidth=3,label='USA')

ax.set_title('Covid-19 Cases',fontsize=20)

ax.set_ylim(0,700000)
ax.set_xlabel('days from tracking',fontsize=14)
ax.set_ylabel('cumulative confirmed cases',fontsize=14)
ax.legend(fontsize=12)

plt.show()

# %% [markdown]
# ### Or, Alternatively:

# %%
fig = plt.figure(figsize=(15,5))

plt.plot(data_italy.values,'-',c='b',linewidth=3,label='Italy')
plt.plot(data_us.values,'-',c='r',linewidth=3,label='USA')
plt.yscale('log')
#plt.ylim(data_italy.values.min(),700000)
plt.xlabel('days from tracking',fontsize=14)
plt.ylabel('cumulative confirmed cases',fontsize=14)
plt.legend(fontsize=12)
plt.title('Covid-19 Confirmed Cases',fontsize=20)

plt.show()

# %% [markdown]
# ## 2c Plot Italy and US data on log axis
#
# Note that we only want the y-axis to be logarithmic

# %%
# your code here

fig,ax = plt.subplots(1,1,figsize=(15,5)) # or whatever dimensions you like

ax.plot(data_italy.values,'-',c='b',linewidth=3,label='Italy')
ax.plot(data_us.values,'-',c='r',linewidth=3,label='USA')
ax.set_yscale('log')

ax.set_title('Covid-19 Cases (Log Scale)',fontsize=20)

ax.set_ylim(1,700000)
ax.set_xlabel('days from tracking',fontsize=14)
ax.set_ylabel('cumulative confirmed cases',fontsize=14)
ax.legend(fontsize=12)

plt.show()

# %% [markdown]
# ## 2d Make the same plot as above, but using a `for` loop

# %%
# your code here
data_list = [data_italy, data_us]
country = ['Italy', 'USA']

fig,ax = plt.subplots(1,1,figsize=(12,8))

for data,name in zip(data_list,country):
    ax.plot(data.values, label=name, linewidth=3)
    
ax.set_title('Covid-19 Cases (Log Scale)',fontsize=20)

ax.set_ylim(1,700000)
ax.set_xlabel('days from tracking',fontsize=14)
ax.set_ylabel('cumulative confirmed cases',fontsize=14)
ax.legend(fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Part 3 Plot Data for 5 countries
#
# Use a for loop, and include x/y labels and a legend. Also save your figure as a jpg and share with friends. You are now a Python datascientist

# %%
import matplotlib as mpl
##Cumulative Cases
countries = ['US', 'Italy', 'Germany', 'Iran', 'Korea, South']

fig,ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
fig.suptitle('Fig. 1: Total Covid-19 Cases',fontsize=26)

for country in countries:
    df_country = df[df['Country/Region'] == country]
    df_country = df_country.set_index('Country/Region', drop = True) # set pandas dataframe index to country
    df_country = df_country.drop(columns=['Lat','Long','Province/State'])
    
    data_country = df_country.loc[country,'2/28/20':'4/17/20']
#    print(data_country)

    for a in ax:
        a.plot(data_country.values, label=country, linewidth=5)
        a.set_xlabel('Days Since Start of Tracking',fontsize=24)
        a.tick_params(labelsize=18)
        a.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
        a.set_xlabel('Days Since Start of Tracking',fontsize=24)
        a.tick_params(labelsize=18)
        a.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
        a.spines['right'].set_visible(False)
        a.spines['top'].set_visible(False)

#ax.set_ylim(1,700000)

ax[0].set_title('Linear Scale', fontsize=20)
ax[0].set_ylabel('Cumulative Confirmed Cases',fontsize=24)
ax[0].legend(fontsize=18,loc='best')
ax[1].set_title('Log Scale', fontsize=20)
ax[1].set_yscale('log')
plt.show()
    

# save your figure
fig.savefig('total_covid.jpg')

# %%
##Per Capita Cases
countries = ['US', 'Italy', 'Germany', 'Iran', 'Korea, South']
per_capita = [331002651, 60461826, 83783942, 83992949, 51269185]

fig,ax = plt.subplots(1,2,figsize=(12,6),constrained_layout=True)
fig.suptitle('Fig. 2: Covid-19 Cases Per Capita',fontsize=26)

for country,pop in zip(countries,per_capita):
    df_country = df[df['Country/Region'] == country]
    df_country = df_country.set_index('Country/Region', drop = True) # set pandas dataframe index to country
    df_country = df_country.drop(columns=['Lat','Long','Province/State'])
    
    data_country = df_country.loc[country,'2/28/20':'4/17/20']
    data_country /= pop
    data_country *= 100
#    print(country, data_country)

    for a in ax:
        a.plot(data_country.values, label=country, linewidth=5)
        a.set_xlabel('Days Since Start of Tracking',fontsize=24)
        a.tick_params(labelsize=18)
        a.spines['right'].set_visible(False)
        a.spines['top'].set_visible(False)

#ax.set_ylim(1,700000)

ax[0].set_title('Linear Scale', fontsize=20)
ax[0].set_ylabel('Cumulative Confirmed Cases\n% Per Capita',fontsize=24)
ax[1].legend(fontsize=18,loc='lower right')
ax[1].set_title('Log Scale', fontsize=20)
ax[1].set_yscale('log')
ax[1].set_ylim()

plt.show()

# save your figure
fig.savefig('percapita_covid.jpg')

# %%
df[df['Country/Region'].str.contains('Korea')]
# Out:
#     Province/State Country/Region   Lat   Long  1/22/20  1/23/20  1/24/20  \
# 143            NaN   Korea, South  36.0  128.0        1        1        2
#
#      1/25/20  1/26/20  1/27/20  ...  4/8/20  4/9/20  4/10/20  4/11/20  \
# 143        2        3        4  ...   10384   10423    10450    10480
#
#      4/12/20  4/13/20  4/14/20  4/15/20  4/16/20  4/17/20
# 143    10512    10537    10564    10591    10613    10635
#
# [1 rows x 91 columns]

# %% [markdown]
# ## Bonus: Seaborn
#
# Plot whatever you like using seaborn

# %%
import seaborn as sns

# %%
longdf = df.rename(columns={'Country/Region':'country'}).set_index('country', drop=True)
# i like to use column names that are all lowercase and that can be identifiers (i.e. variable names)
# see here: https://www.programiz.com/python-programming/keywords-identifier
print('set new index:\n', longdf.head())

longdf = longdf.drop(columns=['Lat', 'Long', 'Province/State'])
longdf.columns.name = 'dates'  # all the columns correspond to dates now, so let's give columns a name
# this column name will show up later after stacking
print('drop unnecessary columns:\n', longdf.head())

longdf = longdf.stack()
# let's give this new series a name
longdf.name = 'cases'
# this series name will show up later after reseting index
print('stack all columns -> creates pd.Series:\n', longdf.head())

longdf = longdf.reset_index()
print('reset index -> creates pd.DataFrame in this case:\n', longdf.head())

print('check the datatypes in each column:\n', longdf.dtypes)
# dates is an object and not a pandas datetime!!! -> we want to have pandas datetime
# luckily pandas has a nice functionality to infer datetimes
# let's reassign date
# and we want dates in units of days
longdf['dates'] = pd.to_datetime(longdf['dates']).astype('datetime64[D]')
print('check the datatypes in each column again:\n', longdf.dtypes)
# Out:
# set new index:
#              Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# country
# Afghanistan            NaN  33.0000  65.0000        0        0        0
# Albania                NaN  41.1533  20.1683        0        0        0
# Algeria                NaN  28.0339   1.6596        0        0        0
# Andorra                NaN  42.5063   1.5218        0        0        0
# Angola                 NaN -11.2027  17.8739        0        0        0
#
#              1/25/20  1/26/20  1/27/20  1/28/20  ...  4/8/20  4/9/20  4/10/20  \
# country                                          ...
# Afghanistan        0        0        0        0  ...     444     484      521
# Albania            0        0        0        0  ...     400     409      416
# Algeria            0        0        0        0  ...    1572    1666     1761
# Andorra            0        0        0        0  ...     564     583      601
# ...

# %%
# this is a very short example of how to use groupby 
# (there are many options of how to use it and what it can spit out, please look at the doc)
# let's align to the day of xth case
no_cases_exceeds = 1

def align_dates(df):
    # groupby will throw the dataframe at you with each groupby iteration for one country in this case
    # take the earliest date where cases exceeds a certain number
    min_date = (df['dates'][df['cases'] > no_cases_exceeds]).min()
    # subtract min_date to get alignment to no_cases_exceeds
    # assign this to a new column
    # and we just care about days with use the timedelta days attribute
    df['aligned_days'] = (df['dates'] - min_date).astype('timedelta64[D]')
    return df

# we get a new longdf with the an additional column called aligned_days
new_longdf = longdf.groupby('country').apply(align_dates)
print(new_longdf.head())
# Out:
#        country      dates  cases  aligned_days
# 0  Afghanistan 2020-01-22      0         -46.0
# 1  Afghanistan 2020-01-23      0         -45.0
# 2  Afghanistan 2020-01-24      0         -44.0
# 3  Afghanistan 2020-01-25      0         -43.0
# 4  Afghanistan 2020-01-26      0         -42.0

# %%
# now we can use seaborn simply to plot, seaborn loves this format
# since the legend is big there is also we can try to restrict to specific countries -> see below

ax = sns.lineplot(
    data=new_longdf, 
    x='aligned_days', 
    y='cases', 
    hue='country', 
    ci=None, 
)

xlims = ax.get_xlim()
ax.set_xlim(0, xlims[1])
# this anchors the legend to the side
ax.legend(bbox_to_anchor=(1,1))

# %%
ax = sns.lineplot(
    data=new_longdf[
        new_longdf['country'].isin([
            'US', 'United Kingdom', 
            'Germany',
            'China', 'Korea, South'
        ])
    ], 
    x='aligned_days', 
    y='cases', 
    hue='country', 
    ci=None, 
)

xlims = ax.get_xlim()
ax.set_xlim(0, xlims[1])
# this anchors the legend to the side
ax.legend(bbox_to_anchor=(1,1))
sns.despine()

# %%
# what about log scale
ax = sns.lineplot(
    data=new_longdf[
        new_longdf['country'].isin([
            'US', 'United Kingdom', 
            'Germany',
            'China', 'Korea, South'
        ])
    ], 
    x='aligned_days', 
    y='cases', 
    hue='country', 
    ci=None, 
)

xlims = ax.get_xlim()
ax.set_xlim(0, xlims[1])
# this anchors the legend to the side
#ax.legend(bbox_to_anchor=(1,1))
ax.set_yscale('log')
sns.despine()

# %%
countries = ['US', 'Italy', 'Germany', 'Iran', 'Korea, South']
per_capita = [331002651, 60461826, 83783942, 83992949, 51269185]

fig,ax = plt.subplots(1,1,figsize=(12,8))

for country,pop in zip(countries,per_capita):
    data_country = new_longdf[new_longdf['country']== country]
    data_country /= pop
    data_country *= 100
    print(country, data_country)

    ax.plot(data_countrydata_country.values, label=country, linewidth=3)
    
ax.set_title('Covid-19 Cases in Population',fontsize=20)

#ax.set_ylim(1,700000)
ax.set_xlabel('Days Since 1st Case',fontsize=14)
ax.set_ylabel('Cumulative Confirmed Cases\n% Per Capita',fontsize=14)
ax.legend(fontsize=12)
plt.yscale('linear')
plt.show()
    

# save your figure
# fig.savefig('myplot.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda/envs/suite2p/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# /anaconda/envs/suite2p/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# /anaconda/envs/suite2p/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...

# %%
new_longdf
# Out:
#            country      dates  cases  aligned_days
# 0      Afghanistan 2020-01-22      0         -46.0
# 1      Afghanistan 2020-01-23      0         -45.0
# 2      Afghanistan 2020-01-24      0         -44.0
# 3      Afghanistan 2020-01-25      0         -43.0
# 4      Afghanistan 2020-01-26      0         -42.0
# 5      Afghanistan 2020-01-27      0         -41.0
# 6      Afghanistan 2020-01-28      0         -40.0
# 7      Afghanistan 2020-01-29      0         -39.0
# 8      Afghanistan 2020-01-30      0         -38.0
# 9      Afghanistan 2020-01-31      0         -37.0
# 10     Afghanistan 2020-02-01      0         -36.0
# 11     Afghanistan 2020-02-02      0         -35.0
# 12     Afghanistan 2020-02-03      0         -34.0
# 13     Afghanistan 2020-02-04      0         -33.0
# 14     Afghanistan 2020-02-05      0         -32.0
# 15     Afghanistan 2020-02-06      0         -31.0
# 16     Afghanistan 2020-02-07      0         -30.0
# ...

# %%
Germany_deaths = 4538
US_deaths = 38910
US_pop = 331002651
Germany_pop = 83783942

US_rate = US_deaths/US_pop * 100

# %%
Germany_rate = Germany_deaths/Germany_pop * 100

# %%
(US_rate/Germany_rate)**-1
# Out:
# 0.4607591229345573
